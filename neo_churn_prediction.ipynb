# %% [markdown]
# # Test bench starter code
#
# This code is just starter code such that anyone can copy-paste own sruff into it and check various things over time, i.e:
#
# * Accuracy of different churn definitions
# * Data drift
# * Model performance over time
#
# The options are endless. This test bench will allow more robust insights into how well models or design decisions might work.

# %%
import gc
from datetime import timedelta
import glob
import pandas as pd

# %% [markdown]
# # Load all train data

# %%
file_pattern = '/kaggle/input/neo-bank-non-sub-churn-prediction/train_*.parquet' 
all_files = glob.glob(file_pattern)
all_files
# Out:
# ['/kaggle/input/neo-bank-non-sub-churn-prediction/train_2008.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2020.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2019.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2010.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2011.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2016.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2017.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2015.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2009.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2021.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2014.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2022.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2018.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2023.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2012.parquet',
#  '/kaggle/input/neo-bank-non-sub-churn-prediction/train_2013.parquet']

# %%
df = pd.concat([pd.read_parquet(file) for file in all_files], ignore_index=True)
df
# Out:
#              Id  customer_id  interest_rate             name    country  \
# 0             1            1            3.5   Yolanda Parker  Lithuania
# 1             6            1            3.5   Yolanda Parker  Lithuania
# 2            16            1            3.5   Yolanda Parker  Lithuania
# 3            31            1            3.5   Yolanda Parker  Lithuania
# 4            50            1            3.5   Yolanda Parker  Lithuania
# ...         ...          ...            ...              ...        ...
# 3926053  848170        13664            0.0  Brittany Potter     Poland
# 3926054  848171        13665            0.0    Angela Garcia      Italy
# 3926055  848172        13666            0.0  Carol Robertson     Poland
# 3926056  848173        13667            0.0     Barry Powell    Austria
# 3926057  848174        13668            0.0     Adam Walters    Denmark
#
#         date_of_birth                                            address  \
# 0          1954-07-10  1929 Erin Lights Suite 709\nLake Michaelburgh,...
# 1          1954-07-10  1929 Erin Lights Suite 709\nLake Michaelburgh,...
# 2          1954-07-10  1929 Erin Lights Suite 709\nLake Michaelburgh,...
# 3          1954-07-10  1929 Erin Lights Suite 709\nLake Michaelburgh,...
# 4          1954-07-10  1929 Erin Lights Suite 709\nLake Michaelburgh,...
# ...               ...                                                ...
# 3926053    1964-10-06  8978 Michele Crossroad Apt. 755\nEast Jasonpor...
# 3926054    1953-03-26  3196 Anna Trail Apt. 801\nWest Christopher, CO...
# 3926055    1976-01-29  5607 James Lock Apt. 409\nClarkborough, UT 416...
# 3926056    1959-04-20  259 Hernandez Glens\nJacobsonland, OK 56372 Au...
# 3926057    1981-03-10  983 Williams Corner\nKimberlyberg, MO 91096 De...
#
#               date  atm_transfer_in  atm_transfer_out  ...  crypto_in_volume  \
# 0       2008-01-17                0                 0  ...        393.145010
# 1       2008-01-18                0                 0  ...        390.005729
# 2       2008-01-19                0                 0  ...        393.209108
# 3       2008-01-20                0                 0  ...        394.078294
# 4       2008-01-21                0                 0  ...        395.174604
# ...            ...              ...               ...  ...               ...
# 3926053 2013-12-31                4                 0  ...         45.546970
# 3926054 2013-12-31                0                 0  ...         56.098345
# 3926055 2013-12-31                0                 0  ...         46.569205
# 3926056 2013-12-31                0                 0  ...         48.731619
# 3926057 2013-12-31                0                 0  ...         45.955594
#
#          crypto_out_volume  complaints               touchpoints  \
# 0               220.900654           0                        []
# 1               221.147296           0                        []
# 2               260.510535           0                        []
# 3               203.214128           0                        []
# 4               207.894467           0  [whatsapp, email, email]
# ...                    ...         ...                       ...
# 3926053          12.188301           0                [whatsapp]
# 3926054          12.743148           0                        []
# 3926055          13.111458           0                        []
# 3926056          14.354938           0                        []
# 3926057          12.386594           0            [email, email]
#
#                                                csat_scores  tenure  \
# 0        {'appointment': None, 'email': None, 'phone': ...       0
# 1        {'appointment': None, 'email': None, 'phone': ...       1
# 2        {'appointment': None, 'email': None, 'phone': ...       2
# 3        {'appointment': None, 'email': None, 'phone': ...       3
# 4        {'appointment': None, 'email': None, 'phone': ...       4
# ...                                                    ...     ...
# 3926053  {'appointment': None, 'email': None, 'phone': ...       0
# 3926054  {'appointment': None, 'email': None, 'phone': ...       0
# 3926055  {'appointment': None, 'email': None, 'phone': ...       0
# 3926056  {'appointment': None, 'email': None, 'phone': ...       0
# 3926057  {'appointment': None, 'email': None, 'phone': ...       0
#
#          from_competitor                                          job  \
# 0                  False                       Amenity horticulturist
# 1                  False                       Amenity horticulturist
# 2                  False                       Amenity horticulturist
# 3                  False                       Amenity horticulturist
# 4                  False                       Amenity horticulturist
# ...                  ...                                          ...
# 3926053            False        Development worker, international aid
# 3926054            False                    Claims inspector/assessor
# 3926055            False                 Designer, exhibition/display
# 3926056             True                       Audiological scientist
# 3926057            False  Armed forces training and education officer
#
#          churn_due_to_fraud model_predicted_fraud
# 0                     False                 False
# 1                     False                 False
# 2                     False                 False
# 3                     False                 False
# 4                     False                 False
# ...                     ...                   ...
# 3926053               False                 False
# 3926054               False                 False
# 3926055               False                 False
# 3926056               False                 False
# 3926057               False                 False
#
# [3926058 rows x 26 columns]

# %% [markdown]
# # Define loop

# %%
def metric_of_choice(*args):
    """Add any evaluation of your choice here."""
    return 0

# %%
df = df.sort_values("date")
min_date = df["date"].min()
max_date = df["date"].max()

window_size_days = 365
window = timedelta(days=window_size_days)
step_size = 365
step = timedelta(days=step_size)

current_train_end = min_date + window

print(f"Min date: {min_date}, max date: {max_date}. Current current_train_end is {current_train_end}.")
# Out:
# Min date: 2008-01-17 00:00:00, max date: 2023-12-31 00:00:00. Current current_train_end is 2009-01-16 00:00:00.

# %%
results = []

while current_train_end <= max_date:
    print(f"Point in time is {current_train_end}")
    current_train_start = current_train_end - window
        
    train_data = df.loc[
        (df["date"] >= current_train_start) &
        (df["date"] < current_train_end)
    ]
    current_test_start, current_test_end = current_train_end, current_train_end + step
    
    test_data = df[(df["date"] >= current_test_start) & (df["date"] < current_test_end)]
    
    # Check if there's enough test data, otherwise break the loop
    if test_data.empty:
        break
    
    print(f"Training from {current_train_start} to {current_train_end}")
    print(f"Testing from {current_test_start} to {current_test_end}")


    # store results
    result_df = pd.DataFrame(
        {
            "train_data_start": [current_train_start],
            "train_data_end": [current_train_end],
            "test_data_start": [current_test_start],
            "test_data_end": [current_test_end],
            "step_size": step_size,
            "window_size_days": window_size_days,
            "metric": metric_of_choice()
        }
    )
    results.append(result_df)


    # Move the training and test windows forward
    current_train_end += step

    del train_data, test_data, result_df
    _ = gc.collect()
# Out:
# Point in time is 2009-01-16 00:00:00
# Training from 2008-01-17 00:00:00 to 2009-01-16 00:00:00
# Testing from 2009-01-16 00:00:00 to 2010-01-16 00:00:00
# Point in time is 2010-01-16 00:00:00
# Training from 2009-01-16 00:00:00 to 2010-01-16 00:00:00
# Testing from 2010-01-16 00:00:00 to 2011-01-16 00:00:00
# Point in time is 2011-01-16 00:00:00
# Training from 2010-01-16 00:00:00 to 2011-01-16 00:00:00
# Testing from 2011-01-16 00:00:00 to 2012-01-16 00:00:00
# Point in time is 2012-01-16 00:00:00
# Training from 2011-01-16 00:00:00 to 2012-01-16 00:00:00
# Testing from 2012-01-16 00:00:00 to 2013-01-15 00:00:00
# Point in time is 2013-01-15 00:00:00
# Training from 2012-01-16 00:00:00 to 2013-01-15 00:00:00
# Testing from 2013-01-15 00:00:00 to 2014-01-15 00:00:00
# Point in time is 2014-01-15 00:00:00
# Training from 2013-01-15 00:00:00 to 2014-01-15 00:00:00
# Testing from 2014-01-15 00:00:00 to 2015-01-15 00:00:00
# Point in time is 2015-01-15 00:00:00
# Training from 2014-01-15 00:00:00 to 2015-01-15 00:00:00
# Testing from 2015-01-15 00:00:00 to 2016-01-15 00:00:00
# Point in time is 2016-01-15 00:00:00
# Training from 2015-01-15 00:00:00 to 2016-01-15 00:00:00
# Testing from 2016-01-15 00:00:00 to 2017-01-14 00:00:00
# Point in time is 2017-01-14 00:00:00
# Training from 2016-01-15 00:00:00 to 2017-01-14 00:00:00
# Testing from 2017-01-14 00:00:00 to 2018-01-14 00:00:00
# Point in time is 2018-01-14 00:00:00
# Training from 2017-01-14 00:00:00 to 2018-01-14 00:00:00
# Testing from 2018-01-14 00:00:00 to 2019-01-14 00:00:00
# Point in time is 2019-01-14 00:00:00
# Training from 2018-01-14 00:00:00 to 2019-01-14 00:00:00
# Testing from 2019-01-14 00:00:00 to 2020-01-14 00:00:00
# Point in time is 2020-01-14 00:00:00
# Training from 2019-01-14 00:00:00 to 2020-01-14 00:00:00
# Testing from 2020-01-14 00:00:00 to 2021-01-13 00:00:00
# Point in time is 2021-01-13 00:00:00
# Training from 2020-01-14 00:00:00 to 2021-01-13 00:00:00
# Testing from 2021-01-13 00:00:00 to 2022-01-13 00:00:00
# Point in time is 2022-01-13 00:00:00
# Training from 2021-01-13 00:00:00 to 2022-01-13 00:00:00
# Testing from 2022-01-13 00:00:00 to 2023-01-13 00:00:00
# Point in time is 2023-01-13 00:00:00
# Training from 2022-01-13 00:00:00 to 2023-01-13 00:00:00
# Testing from 2023-01-13 00:00:00 to 2024-01-13 00:00:00

# %% [markdown]
# # Collecting results
#
# In this part we just union all results and can begin doing deeper analysis.

# %%
results_df = pd.concat(results)
results_df
# Out:
#   train_data_start train_data_end test_data_start test_data_end  step_size  \
# 0       2008-01-17     2009-01-16      2009-01-16    2010-01-16        365
# 0       2009-01-16     2010-01-16      2010-01-16    2011-01-16        365
# 0       2010-01-16     2011-01-16      2011-01-16    2012-01-16        365
# 0       2011-01-16     2012-01-16      2012-01-16    2013-01-15        365
# 0       2012-01-16     2013-01-15      2013-01-15    2014-01-15        365
# 0       2013-01-15     2014-01-15      2014-01-15    2015-01-15        365
# 0       2014-01-15     2015-01-15      2015-01-15    2016-01-15        365
# 0       2015-01-15     2016-01-15      2016-01-15    2017-01-14        365
# 0       2016-01-15     2017-01-14      2017-01-14    2018-01-14        365
# 0       2017-01-14     2018-01-14      2018-01-14    2019-01-14        365
# 0       2018-01-14     2019-01-14      2019-01-14    2020-01-14        365
# 0       2019-01-14     2020-01-14      2020-01-14    2021-01-13        365
# 0       2020-01-14     2021-01-13      2021-01-13    2022-01-13        365
# 0       2021-01-13     2022-01-13      2022-01-13    2023-01-13        365
# 0       2022-01-13     2023-01-13      2023-01-13    2024-01-13        365
#
#    window_size_days  metric
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0
# 0               365       0

# %%
results_df["metric"].describe()
# Out:
# count    15.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: metric, dtype: float64
